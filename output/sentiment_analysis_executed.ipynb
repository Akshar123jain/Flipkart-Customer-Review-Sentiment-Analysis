# %%
import pandas as pd

data = pd.read_csv("Dataset/flipkart_reviews.csv")

print(data)
# Out:
#               Review Sentiment
# 0  Excellent product  Positive
# 1  Very good quality  Positive
# 2        Bad product  Negative
# 3     Waste of money  Negative
# 4    Average product   Neutral
# 5      Fast delivery  Positive
# 6      Late delivery  Negative
# 7    Amazing quality  Positive
